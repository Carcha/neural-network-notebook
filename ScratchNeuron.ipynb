# %% [markdown]
# * Example inputs, weihgts, and bias
#
#  Neuron Representation
#      Input1 \
#      Input2 - O -- Output
#      Input3 / |
#               Bias

# %%
inputs = [1, 2, 3, 2.5]

weights1 = [0.2, 0.8, -0.5, 1.0]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]
weights = [weights1, weights2, weights3]

bias1 = 2
bias2 = 3
bias3 = 0.5
bias = [2, 3, 0.5]


# Neuron output formula
# output = [inputs[0]*weights1[0] + inputs[1]*weights1[1] + inputs[2]*weights1[2] + inputs[3]*weights1[3] + biases[0],
# inputs[0]*weights2[0] + inputs[1]*weights2[1] + inputs[2]*weights2[2] + inputs[3]*weights2[3] + biases[1],
# inputs[0]*weights3[0] + inputs[1]*weights3[1] + inputs[2]*weights3[2] + inputs[3]*weights3[3] + biases[2]]

output = []

# This loop represents the formula for the ouuput calculation
for indexW, weight in enumerate(weights):
	element = 0
	list = []
	for index, value in enumerate(weight):
		element = element + inputs[index]*weight[index]
	element = element + bias[indexW]
	output.append(element)

print(output)
# Out:
# [4.8, 1.21, 2.385]
